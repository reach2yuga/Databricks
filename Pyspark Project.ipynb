# %% [markdown]
# Create Sales Data Frame

# %%
from pyspark.sql.types import StructType,StructField,IntegerType,StringType,DateType
schema = StructType([
    StructField("product_id",IntegerType(),True),
    StructField("customer_id",StringType(),True),
    StructField("order_date",DateType(),True),
    StructField("location",StringType(),True),
    StructField("location2",StringType(),True)

])

sales_df = spark.read.format("csv").option("inferschema","true").schema(schema).load("/Volumes/workspace/default/pyspark-project-files/sales.csv.txt")
display(sales_df)

# %% [markdown]
# derive month,year,Quarter

# %%
from pyspark.sql.functions import month, year,quarter

sales_df = sales_df.withColumn("Order_Year",year(sales_df.order_date))
sales_df = sales_df.withColumn("Order_month",month(sales_df.order_date))
sales_df = sales_df.withColumn("Order_quarter",quarter(sales_df.order_date))
display(sales_df)

# %% [markdown]
# Create Menu Data frame

# %%
from pyspark.sql.types import StructType,StructField,IntegerType,StringType,DateType
schema = StructType([
    StructField("product_id",IntegerType(),True),
    StructField("product_name",StringType(),True),
    StructField("price",StringType(),True)
])

menu_df = spark.read.format("csv").option("inferschema","true").schema(schema).load("/Volumes/workspace/default/pyspark-project-files/menu.csv.txt")
display(menu_df)

# %% [markdown]
# Total Amount spend by each customer

# %%
total_amount_spent = (sales_df.join(menu_df,'product_id')
                        .groupBy('customer_id')
                        .agg({'price':'sum'})
                        .orderBy('customer_id'))
display(total_amount_spent)
# Out:
# Databricks visualization. Run in Databricks to view.

# %% [markdown]
# Spend by category

# %%
total_amount_spend_by_category = (sales_df.join(menu_df,'product_id')
                        .groupBy('product_name')
                        .agg({'price':'sum'})
                        .orderBy('product_name'))
display(total_amount_spent)
# Out:
# Databricks visualization. Run in Databricks to view.

# %% [markdown]
# Total amount of sale in each month

# %%
Monthly_Sale = (sales_df.join(menu_df,'product_id')
                        .groupBy('order_month')
                        .agg({'price':'sum'})
                        .orderBy('order_month'))
                        
display(total_amount_spent)
# Out:
# Databricks visualization. Run in Databricks to view.

# %%
Monthly_Sale = (sales_df.join(menu_df,'product_id')
                        .groupBy('order_year')
                        .agg({'price':'sum'})
                        .orderBy('order_year'))
                        
display(total_amount_spent)
# Out:
# Databricks visualization. Run in Databricks to view.

# %% [markdown]
# How many times each product purchased

# %%
from pyspark.sql.functions import count
most_df = (sales_df.join(menu_df, 'product_id').groupBy('product_id','product_name').agg(count('product_id').alias('product_count')).orderBy('product_count',ascending =0).drop('product_id'))
display(most_df)
# Out:
# Databricks visualization. Run in Databricks to view.

# %% [markdown]
# Top order items

# %%
from pyspark.sql.functions import count
most_df = (sales_df.join(menu_df, 'product_id').groupBy('product_id','product_name').agg(count('product_id').alias('product_count')).orderBy('product_count',ascending =0).drop('product_id').limit(1))
display(most_df)
# Out:
# Databricks visualization. Run in Databricks to view.

# %% [markdown]
# Frequency of customer visited to restruratnt

# %%
from pyspark.sql.functions import countDistinct

df = (sales_df.filter(sales_df.location2 == 'Restaurant')
    .groupBy('customer_id') 
    .agg(countDistinct('order_date'))
)

display(df)
# Out:
# Databricks visualization. Run in Databricks to view.
